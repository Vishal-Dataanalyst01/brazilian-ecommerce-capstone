# %%
# 📦 Step 1: Load dataset
import pandas as pd
file_path = r'C:\Users\Admin\Documents\GitHub\brazilian-ecommerce-capstone\data\raw\olist_order_payments_dataset.csv'
df_payments = pd.read_csv(file_path)
df_payments.info()
df_payments.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
# ...

# %%
# 🔍 Step 2: Check for nulls
df_payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %%
# 📊 Step 3: Histogram – Payment Value Distribution
df_payments['payment_value'].plot(kind='hist', bins=30, figsize=(8, 5), title='Payment Value Distribution')
# Out:
# <Axes: title={'center': 'Payment Value Distribution'}, ylabel='Frequency'>

# %%
# 📊 Step 4: Bar Chart – Payment Type Distribution
df_payments['payment_type'].value_counts().plot(kind='bar', title='Payment Method Usage', figsize=(8, 5))
# Out:
# <Axes: title={'center': 'Payment Method Usage'}, xlabel='payment_type'>

# %%
# 📊 Step 5: Box Plot – Payment Installments
df_payments.boxplot(column='payment_installments', figsize=(6, 4))
# Out:
# <Axes: >
