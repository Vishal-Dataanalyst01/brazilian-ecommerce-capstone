# %%
import pandas as pd
file_path = r'C:\Users\Admin\Documents\GitHub\brazilian-ecommerce-capstone\data\raw\olist_customers_dataset.csv'
df_customers = pd.read_csv(file_path)
df_customers.info()
df_customers.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
# ...

# %%
df_customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %%
state_counts = df_customers['customer_state'].value_counts()
state_counts.plot(kind='bar', figsize=(10,5), title='Number of Customers by State')
# Out:
# <Axes: title={'center': 'Number of Customers by State'}, xlabel='customer_state'>

# %%
# 📊 Step 4: Count of unique customers per city (Top 20)
city_counts = df_customers['customer_city'].value_counts().head(20)
city_counts.plot(kind='barh', figsize=(10,8), title='Top 20 Cities by Customer Count')
# Out:
# <Axes: title={'center': 'Top 20 Cities by Customer Count'}, ylabel='customer_city'>
